# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 14456644471661659952, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 11297803469
#  locality {
#    bus_id: 1
#  }
#  incarnation: 8159459750714895267
#  physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"]

# %%
# !pip3 install -U keras
# Out:
# Collecting keras
#   Downloading Keras-2.1.4-py2.py3-none-any.whl (322kB)
#     100% |████████████████████████████████| 327kB 2.4MB/s
# Collecting scipy>=0.14 (from keras)
#   Downloading scipy-1.0.0-cp36-cp36m-manylinux1_x86_64.whl (50.0MB)
#     100% |████████████████████████████████| 50.0MB 28kB/s
# Collecting numpy>=1.9.1 (from keras)
#   Downloading numpy-1.14.1-cp36-cp36m-manylinux1_x86_64.whl (12.2MB)
#     100% |████████████████████████████████| 12.2MB 114kB/s
# Requirement already up-to-date: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras)
# Collecting pyyaml (from keras)
#   Downloading PyYAML-3.12.tar.gz (253kB)
#     100% |████████████████████████████████| 256kB 4.2MB/s
# Building wheels for collected packages: pyyaml
# done
#   Stored in directory: /content/.cache/pip/wheels/2c/f7/79/13f3a12cd723892437c0cfbde1230ab4d82947ff7b3839a4fc
# Successfully built pyyaml
# Installing collected packages: numpy, scipy, pyyaml, keras
#   Found existing installation: numpy 1.14.0
#     Uninstalling numpy-1.14.0:
#       Successfully uninstalled numpy-1.14.0
#   Found existing installation: scipy 0.19.1
#     Uninstalling scipy-0.19.1:
#       Successfully uninstalled scipy-0.19.1
#   Found existing installation: PyYAML 3.11
#     Uninstalling PyYAML-3.11:
#       Successfully uninstalled PyYAML-3.11
# Successfully installed keras-2.1.4 numpy-1.14.1 pyyaml-3.12 scipy-1.0.0

# %%
# is GPU working?

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 15562436351624862119, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 356515840
#  locality {
#    bus_id: 1
#  }
#  incarnation: 13719083721224028999
#  physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"]

# %%
# !pip3 install -q xgboost==0.4a30

# %%
import xgboost

# %%
# !pip3 install -q lightgbm

# %%
import lightgbm

# %%
# https://medium.com/deep-learning-turkey/google-colab-free-gpu-tutorial-e113627b9f5d

# %%
print(f'{lightgbm.__version__}')
# Out:
# 2.1.0

# %%
import pandas as pd

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13341960 kB
# MemFree:         3846928 kB
# MemAvailable:   11740548 kB
# Buffers:          656204 kB
# Cached:          6861488 kB
# SwapCached:            0 kB
# Active:          3831056 kB
# Inactive:        4552636 kB
# Active(anon):    1026264 kB
# Inactive(anon):   123440 kB
# Active(file):    2804792 kB
# Inactive(file):  4429196 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               456 kB
# Writeback:             0 kB
# AnonPages:        866044 kB
# Mapped:           398208 kB
# Shmem:            283716 kB
# Slab:             942756 kB
# SReclaimable:     913048 kB
# SUnreclaim:        29708 kB
# KernelStack:        3280 kB
# PageTables:         6580 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6670980 kB
# Committed_AS:    2211708 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:           0 kB
# VmallocChunk:          0 kB
# AnonHugePages:      2048 kB
# HugePages_Total:       0
# HugePages_Free:        0
# HugePages_Rsvd:        0
# HugePages_Surp:        0
# Hugepagesize:       2048 kB
# DirectMap4k:      167884 kB
# DirectMap2M:     7172096 kB
# DirectMap1G:     8388608 kB

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc eagerfpu pni pclmulqdq ssse3 fma cx16 sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms xsaveopt
# bugs		:
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc eagerfpu pni pclmulqdq ssse3 fma cx16 sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms xsaveopt
# bugs		:
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
